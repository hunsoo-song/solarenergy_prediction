# %%
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
os.chdir("E:\\COMS\\Y2018\\M12\D15\\")
f = open('coms_le1b_ir1_ch1_k_201812150300.bin','rb')
bdata = f.read()
bdata_np=np.frombuffer(bdata, dtype=np.uint16)
bdata_np_reshape = np.reshape(bdata_np,[1024,1024])
plt.imshow(bdata_np_reshape)

# %%
os.chdir("E:\\COMS\\Y2018\\M12\D15\\")
f = open('coms_le1b_ir1_ch1_k_201812150300.bin','rb')
bdata = f.read()
bdata_np=np.frombuffer(bdata, dtype=np.uint16)
bdata_np_reshape = np.reshape(bdata_np,[1024,1024])
plt.imshow(bdata_np_reshape)

# %%
plt.imshow(bdata_np_reshape[600:700,450:550])

# %%
os.chdir("E:\\COMS\\Y2018\\M12\D15\\")
f = open('coms_le1b_swir_ch4_k_201812150300.bin','rb')
bdata = f.read()
bdata_np=np.frombuffer(bdata, dtype=np.uint16)
bdata_np_reshape = np.reshape(bdata_np,[1024,1024])
plt.imshow(bdata_np_reshape)

# %%
os.chdir("E:\\COMS\\Y2018\\M12\D15\\")
f = open('coms_le1b_ir1_ch1_k_201812150300.bin','rb')
bdata = f.read()
bdata_np=np.frombuffer(bdata, dtype=np.uint16)
bdata_np_reshape = np.reshape(bdata_np,[1024,1024])
plt.imshow(bdata_np_reshape[0:100,0:1024])

# %%
bdata_np_reshape[1,2]
# Out:
# 40706

# %%
type(bdata_np_reshape)
# Out:
# numpy.ndarray

# %%
np.mean(bdata_np_reshape)
# Out:
# 31108.31026172638

# %%
os.chdir("E:\\COMS\\Y2018\\M12\D15\\")
f = open('coms_le1b_ir2_ch2_k_201812150300.bin','rb')
bdata = f.read()
bdata_np=np.frombuffer(bdata, dtype=np.uint16)
bdata_np_reshape = np.reshape(bdata_np,[1024,1024])
plt.imshow(bdata_np_reshape)

# %%
os.chdir("E:\\COMS\\Y2018\\M12\D15\\")
f = open('coms_le1b_wv_ch3_k_201812150300.bin','rb')
bdata = f.read()
bdata_np=np.frombuffer(bdata, dtype=np.uint16)
bdata_np_reshape = np.reshape(bdata_np,[1024,1024])
plt.imshow(bdata_np_reshape)

# %%
os.chdir("E:\\COMS\\Y2018\\M12\D15\\")
f = open('coms_le1b_swir_ch4_k_201812150300.bin','rb')
bdata = f.read()
bdata_np=np.frombuffer(bdata, dtype=np.uint16)
bdata_np_reshape = np.reshape(bdata_np,[1024,1024])
plt.imshow(bdata_np_reshape)

# %%
os.chdir("E:\\COMS\\Y2018\\M12\D15\\")
f = open('coms_le1b_vis_ch5_k_201812150300.bin','rb')
bdata = f.read()
bdata_np=np.frombuffer(bdata, dtype=np.uint16)
bdata_np_reshape = np.reshape(bdata_np,[1024,1024])
plt.imshow(bdata_np_reshape)

# %%
bdata_np_reshape[500,500]
# Out:
# 46594

# %%
os.chdir("C:\\Users\\Hunsoo\\Desktop\\SK\\천리안\\dd\\coms_le1b_ir2_ch2_k_201903220500.bin")
f = open('coms_le1b_ir2_ch2_k_201903220500.bin','rb')
bdata = f.read()
bdata_np=np.frombuffer(bdata, dtype=np.uint16)
bdata_np_reshape = np.reshape(bdata_np,[1024,1024])
plt.imshow(bdata_np_reshape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-57f05772cbac> in <module>
# ----> 1 os.chdir("C:\\Users\\Hunsoo\\Desktop\\SK\\천리안\\dd\\coms_le1b_ir2_ch2_k_201903220500.bin")
#       2 f = open('coms_le1b_ir2_ch2_k_201903220500.bin','rb')
#       3 bdata = f.read()
#       4 bdata_np=np.frombuffer(bdata, dtype=np.uint16)
#       5 bdata_np_reshape = np.reshape(bdata_np,[1024,1024])
#
# FileNotFoundError: [WinError 3] 지정된 경로를 찾을 수 없습니다: 'C:\\Users\\Hunsoo\\Desktop\\SK\\천리안\\dd\\coms_le1b_ir2_ch2_k_201903220500.bin'

# %%
os.chdir("C:\\Users\\Hunsoo\\Desktop\\SK\\천리안\\dd\\coms_le1b_wv_ch3_k_201903220500.bin")
f = open('coms_le1b_wv_ch3_k_201903220500.bin','rb')
bdata = f.read()
bdata_np=np.frombuffer(bdata, dtype=np.uint16)
bdata_np_reshape = np.reshape(bdata_np,[1024,1024])
plt.imshow(bdata_np_reshape)

# %%
os.chdir("C:\\Users\\Hunsoo\\Desktop\\SK\\천리안\\dd\\coms_le1b_swir_ch4_k_201903220500.bin")
f = open('coms_le1b_swir_ch4_k_201903220500.bin','rb')
bdata = f.read()
bdata_np=np.frombuffer(bdata, dtype=np.uint16)
bdata_np_reshape = np.reshape(bdata_np,[1024,1024])
plt.imshow(bdata_np_reshape)

# %%
os.chdir("C:\\Users\\Hunsoo\\Desktop\\SK\\천리안\\dd\\coms_le1b_vis_ch5_k_201903220500.bin")
f = open('coms_le1b_vis_ch5_k_201903220500.bin','rb')
bdata = f.read()
bdata_np=np.frombuffer(bdata, dtype=np.uint16)
bdata_np_reshape = np.reshape(bdata_np,[1024,1024])
plt.imshow(bdata_np_reshape)

# %%
bdata_np_reshape
# Out:
# array([[43776, 43264, 43008, ..., 19968, 19968, 19456],
#        [44288, 44288, 41216, ..., 19968, 19712, 19712],
#        [43008, 44800, 42496, ..., 20224, 19712, 19968],
#        ...,
#        [ 5889,  4097,  3841, ..., 44033, 42753, 41473],
#        [ 6145,  7425,  2049, ..., 44801, 43521, 50433],
#        [ 3841,  7425,  2561, ..., 35841, 43777, 36097]], dtype=uint16)

# %%
plt.hist(bdata_np, bins='auto')
# Out:
# (array([ 2615.,  1388.,  2637.,  1358.,  2639.,  1295.,  2573.,  1292.,
#          2574.,  1281.,  2431.,  1236.,  2405.,  1184.,  2403.,  1216.,
